# %% [markdown]
# # google colabの環境を確認

# %% [markdown]
# - google colabはpythonのクラウド環境です。
# - Linuxの仮想マシン上で実行され、jupyter-notebookによく似た開発環境です。
# - Localマシンに必要なのはブラウザのみで、Linux, Windows, Mac 共通で走ります。
#
# Pythonの標準環境の目安としてgoogle colabの環境を確認しておきます

# %% [markdown]
# ### OSバージョン
# ipythonのマジックコマンド '!' を使って　Linux-OS のコマンドをたたき仮想環境を確認します

# %%
# !cat /etc/issue
# Out:
# Ubuntu 18.04.3 LTS \n \l

# %%
  # !の次のコマンド有効範囲はこのセル内です
  # !python --version
# Out:
# Python 3.6.8

# %% [markdown]
# ### 主要なパッケージのバージョンを確認しておきます

# %%
pkglist = ['keras', 'tensorflow', 'numpy', 'scikit-learn', 'matplotlib', 'seaborn', 'pandas']

# %%
import pkg_resources

for dist in pkg_resources.working_set:
    if dist.project_name in pkglist:
        print(dist.project_name, dist.version)
# Out:
# tensorflow 1.14.0
# seaborn 0.9.0
# scikit-learn 0.21.3
# pandas 0.24.2
# numpy 1.16.5
# matplotlib 3.0.3

# %% [markdown]
# おやおや、kerasがありませんね<br>
# import してみます

# %%
import keras
# Out:
# Using TensorFlow backend.

# %% [markdown]
# kerasはtensorflowに含まれているという解釈でいいのでしょう（か？）

# %%
keras.__version__
# Out:
# '2.2.5'

# %%
import tensorflow
tensorflow.__version__
# Out:
# '1.14.0'
